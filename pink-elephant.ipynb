# %%
import pandas as pd

# %%
df = pd.read_csv('ThermochronTracking Elephants Kruger 2007.csv')
df.head(100)
# Out:
#       event-id  visible                timestamp  location-long  location-lat  \
# 0   9421351127     True  2007-08-13 00:30:00.000       31.87091     -24.81373
# 1   9421351128     True  2007-08-13 02:00:00.000       31.87399     -24.81483
# 2   9421351129     True  2007-08-13 03:31:00.000       31.87724     -24.81673
# 3   9421351130     True  2007-08-13 04:00:00.000       31.87822     -24.81569
# 4   9421351131     True  2007-08-13 06:00:00.000       31.89554     -24.79870
# ..         ...      ...                      ...            ...           ...
# 95  9421351222     True  2007-08-19 19:00:00.000       31.89140     -24.75769
# 96  9421351223     True  2007-08-19 19:30:00.000       31.89208     -24.75418
# 97  9421351224     True  2007-08-19 23:00:00.000       31.89560     -24.73711
# 98  9421351225     True  2007-08-19 23:30:00.000       31.89533     -24.73632
# 99  9421351226     True  2007-08-20 00:00:00.000       31.89521     -24.73573
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283688 entries, 0 to 283687
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   event-id                         283688 non-null  int64
#  1   visible                          283688 non-null  bool
#  2   timestamp                        283688 non-null  object
#  3   location-long                    283688 non-null  float64
#  4   location-lat                     283688 non-null  float64
#  5   external-temperature             283688 non-null  float64
#  6   sensor-type                      283688 non-null  object
#  7   individual-taxon-canonical-name  283688 non-null  object
#  8   tag-local-identifier             283688 non-null  object
#  9   individual-local-identifier      283688 non-null  object
#  10  study-name                       283688 non-null  object
# dtypes: bool(1), float64(3), int64(1), object(6)
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df['location-long'],df['location-lat'],color='yellow', linewidth=0.2)

# %%
import seaborn as sns

# %%
sns.lineplot(data=df, x=df['location-long'], y=df['location-lat'], color='yellow')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sns.lineplot(data=df, x=df['location-long'], y=df['location-lat'], color='yellow')
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\seaborn\relational.py:441, in _LinePlotter.plot(self, ax, kws)
#     438     grouped = sub_data.groupby(orient, sort=self.sort)
# ...

# %%
df = df.rename(
    columns={'tag-local-identifier': 'tag_id',
     'location-lat': 'lat',
     'location-long': 'long',
     })
df.head()
# Out:
#      event-id  visible                timestamp      long       lat  \
# 0  9421351127     True  2007-08-13 00:30:00.000  31.87091 -24.81373
# 1  9421351128     True  2007-08-13 02:00:00.000  31.87399 -24.81483
# 2  9421351129     True  2007-08-13 03:31:00.000  31.87724 -24.81673
# 3  9421351130     True  2007-08-13 04:00:00.000  31.87822 -24.81569
# 4  9421351131     True  2007-08-13 06:00:00.000  31.89554 -24.79870
#
#    external-temperature sensor-type individual-taxon-canonical-name tag_id  \
# 0                  24.0         gps              Loxodonta africana  AM105
# 1                  23.0         gps              Loxodonta africana  AM105
# 2                  21.0         gps              Loxodonta africana  AM105
# 3                  21.0         gps              Loxodonta africana  AM105
# 4                  22.0         gps              Loxodonta africana  AM105
#
#   individual-local-identifier                                 study-name
# ...

# %%
df_stefan = df[df['tag_id'] == 'AM105']

# %%
df_stefan
# Out:
#          event-id  visible                timestamp      long       lat  \
# 0      9421351127     True  2007-08-13 00:30:00.000  31.87091 -24.81373
# 1      9421351128     True  2007-08-13 02:00:00.000  31.87399 -24.81483
# 2      9421351129     True  2007-08-13 03:31:00.000  31.87724 -24.81673
# 3      9421351130     True  2007-08-13 04:00:00.000  31.87822 -24.81569
# 4      9421351131     True  2007-08-13 06:00:00.000  31.89554 -24.79870
# ...           ...      ...                      ...       ...       ...
# 15093  9421366220     True  2009-08-12 19:30:00.000  31.81571 -24.71985
# 15094  9421366221     True  2009-08-12 20:00:00.000  31.81562 -24.71988
# 15095  9421366222     True  2009-08-12 20:30:00.000  31.81518 -24.72014
# 15096  9421366223     True  2009-08-12 21:00:00.000  31.81211 -24.72042
# 15097  9421366224     True  2009-08-12 21:30:00.000  31.81086 -24.72041
#
#        external-temperature sensor-type individual-taxon-canonical-name  \
# ...

# %%
# sns.lineplot(x=df_stefan['long'], y=df_stefan['lat'])
plt.plot(df_stefan['long'],df_stefan['lat'],linewidth=0.2)

# %%
df_stefan['timestamp']
# Out:
# 0        2007-08-13 00:30:00.000
# 1        2007-08-13 02:00:00.000
# 2        2007-08-13 03:31:00.000
# 3        2007-08-13 04:00:00.000
# 4        2007-08-13 06:00:00.000
#                   ...
# 15093    2009-08-12 19:30:00.000
# 15094    2009-08-12 20:00:00.000
# 15095    2009-08-12 20:30:00.000
# 15096    2009-08-12 21:00:00.000
# 15097    2009-08-12 21:30:00.000
# Name: timestamp, Length: 15098, dtype: object

# %%
df_stefan[['date', 'time']] = df_stefan.timestamp.str.split(" ", expand = True)
df_stefan
# df_stefan['day'] =pd.to_datetime(df_stefan['timestamp'], format='%Y%m%d').date()
# Out:
# C:\Users\JinshuPan\AppData\Local\Temp\ipykernel_3168\3324185987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stefan[['date', 'time']] = df_stefan.timestamp.str.split(" ", expand = True)
# C:\Users\JinshuPan\AppData\Local\Temp\ipykernel_3168\3324185987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stefan[['date', 'time']] = df_stefan.timestamp.str.split(" ", expand = True)
#          event-id  visible                timestamp      long       lat  \
# ...

# %%
df_lil_stefan = df_stefan.groupby(df_stefan['date']).min()
df_lil_stefan
# Out:
#               event-id  visible                timestamp      long       lat  \
# date
# 2007-08-13  9421351127     True  2007-08-13 00:30:00.000  31.87091 -24.81673
# 2007-08-14  9421351140     True  2007-08-14 00:00:00.000  31.89472 -24.74839
# 2007-08-15  9421351155     True  2007-08-15 00:01:00.000  31.89832 -24.74029
# 2007-08-16  9421351167     True  2007-08-16 00:00:00.000  31.88630 -24.77435
# 2007-08-17  9421351190     True  2007-08-17 03:00:00.000  31.88799 -24.77082
# ...                ...      ...                      ...       ...       ...
# 2009-08-08  9421366082     True  2009-08-08 04:30:00.000  31.79246 -24.72678
# 2009-08-09  9421366100     True  2009-08-09 00:01:00.000  31.79124 -24.73764
# 2009-08-10  9421366126     True  2009-08-10 00:01:00.000  31.79198 -24.72796
# 2009-08-11  9421366157     True  2009-08-11 00:00:00.000  31.79326 -24.73607
# 2009-08-12  9421366191     True  2009-08-12 00:00:00.000  31.79128 -24.74313
#
# ...

# %%
plt.plot(df_lil_stefan['long'],df_lil_stefan['lat'],linewidth=0.2)

# %%
df_2 = df_lil_stefan.drop(columns=['event-id', 'visible', 'sensor-type','individual-local-identifier','individual-taxon-canonical-name', 'study-name'])

# %%
df_2
# Out:
#                           timestamp      long       lat  external-temperature  \
# date
# 2007-08-13  2007-08-13 00:30:00.000  31.87091 -24.81673                  21.0
# 2007-08-14  2007-08-14 00:00:00.000  31.89472 -24.74839                  20.0
# 2007-08-15  2007-08-15 00:01:00.000  31.89832 -24.74029                  22.0
# 2007-08-16  2007-08-16 00:00:00.000  31.88630 -24.77435                  19.0
# 2007-08-17  2007-08-17 03:00:00.000  31.88799 -24.77082                  19.0
# ...                             ...       ...       ...                   ...
# 2009-08-08  2009-08-08 04:30:00.000  31.79246 -24.72678                  24.0
# 2009-08-09  2009-08-09 00:01:00.000  31.79124 -24.73764                  21.0
# 2009-08-10  2009-08-10 00:01:00.000  31.79198 -24.72796                  19.0
# 2009-08-11  2009-08-11 00:00:00.000  31.79326 -24.73607                  18.0
# 2009-08-12  2009-08-12 00:00:00.000  31.79128 -24.74313                  19.0
#
# ...
